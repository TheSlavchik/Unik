# %%
import unittest
from analysis import analyze_dependence, compare_variants

# %% [markdown]
# # Юнит тесты

# %%
unittest.main(module='test_bloom_filter', argv=[''], exit=False)
# Out:
# ......
# ----------------------------------------------------------------------
# Ran 6 tests in 0.945s
#
# OK

# %% [markdown]
# # Графики и таблица

# %%
analyze_dependence()
# Out:
#         n   eps      m  k  fill fill_percent  theoretical_fp  practical_fp
# 0   15000  0.90   3289  1  0.25          25%        0.680233      0.676800
# 1   15000  0.90   3289  1  0.50          50%        0.897749      0.905800
# 2   15000  0.90   3289  1  0.75          75%        0.967304      0.968333
# 3   15000  0.90   3289  1  0.95          95%        0.986867      0.986800
# 4   15000  0.70  11135  1  0.25          25%        0.285931      0.279000
# 5   15000  0.70  11135  1  0.50          50%        0.490106      0.489200
# 6   15000  0.70  11135  1  0.75          75%        0.635900      0.629133
# 7   15000  0.70  11135  1  0.95          95%        0.721893      0.718200
# 8   15000  0.50  21640  1  0.25          25%        0.159106      0.159200
# 9   15000  0.50  21640  1  0.50          50%        0.292898      0.293867
# 10  15000  0.50  21640  1  0.75          75%        0.405403      0.404867
# ...

# %%
compare_variants()
# Out:
# n=25000, eps=0.7
# Precalculated parameters: m=18559, k=1
# fill=25%: P(fp)=0.285923
# fill=50%: P(fp)=0.490093
# fill=75%: P(fp)=0.635887
# fill=95%: P(fp)=0.721880
#
#
# n=130000, eps=0.15
# Precalculated parameters: m=513318, k=2
# fill=25%: P(fp)=0.014146
# fill=50%: P(fp)=0.050055
# fill=75%: P(fp)=0.099892
# fill=95%: P(fp)=0.145885
#
#
# n=750000, eps=0.05
# Precalculated parameters: m=4676418, k=4
# fill=25%: P(fp)=0.000482
# fill=50%: P(fp)=0.005670
# fill=75%: P(fp)=0.021276
# fill=95%: P(fp)=0.043368
