# %%
import unittest
from analysis import analyze_dependence, compare_variants

# %% [markdown]
# # Юнит тесты

# %%
unittest.main(module='test_bloom_filter', argv=[''], exit=False)
# Out:
# ......
# ----------------------------------------------------------------------
# Ran 6 tests in 1.146s
#
# OK

# %% [markdown]
# # Графики и таблица

# %%
analyze_dependence()
# Out:
#         n   eps      m  k  fill fill_percent  theoretical_fp  practical_fp
# 0   15000  0.90   3289  1  0.25          25%        0.680233      0.679333
# 1   15000  0.90   3289  1  0.50          50%        0.897749      0.897400
# 2   15000  0.90   3289  1  0.75          75%        0.967304      0.968800
# 3   15000  0.90   3289  1  0.95          95%        0.986867      0.987733
# 4   15000  0.70  11135  1  0.25          25%        0.285931      0.283467
# 5   15000  0.70  11135  1  0.50          50%        0.490106      0.496467
# 6   15000  0.70  11135  1  0.75          75%        0.635900      0.650467
# 7   15000  0.70  11135  1  0.95          95%        0.721893      0.719667
# 8   15000  0.50  21640  1  0.25          25%        0.159106      0.156800
# 9   15000  0.50  21640  1  0.50          50%        0.292898      0.292933
# 10  15000  0.50  21640  1  0.75          75%        0.405403      0.409133
# 11  15000  0.50  21640  1  0.95          95%        0.482374      0.484267
# 12  15000  0.30  37588  1  0.25          25%        0.094951      0.096333
# 13  15000  0.30  37588  1  0.50          50%        0.180886      0.177467
# 14  15000  0.30  37588  1  0.75          75%        0.258661      0.254600
# 15  15000  0.30  37588  1  0.95          95%        0.315530      0.321133
# 16  15000  0.10  71887  3  0.25          25%        0.003040      0.002600
# 17  15000  0.10  71887  3  0.50          50%        0.019410      0.019067
# 18  15000  0.10  71887  3  0.75          75%        0.052598      0.053467
# 19  15000  0.10  71887  3  0.95          95%        0.090074      0.090667
# 20  15000  0.05  93528  4  0.25          25%        0.000482      0.000533
# 21  15000  0.05  93528  4  0.50          50%        0.005670      0.005267
# 22  15000  0.05  93528  4  0.75          75%        0.021276      0.021867
# 23  15000  0.05  93528  4  0.95          95%        0.043369      0.043200

# %%
compare_variants()
# Out:
# n=25000, eps=0.7
# Precalculated parameters: m=18559, k=1
# fill=25%: P(fp)=0.285923
# fill=50%: P(fp)=0.490093
# fill=75%: P(fp)=0.635887
# fill=95%: P(fp)=0.721880
#
#
# n=130000, eps=0.15
# Precalculated parameters: m=513318, k=2
# fill=25%: P(fp)=0.014146
# fill=50%: P(fp)=0.050055
# fill=75%: P(fp)=0.099892
# fill=95%: P(fp)=0.145885
#
#
# n=750000, eps=0.05
# Precalculated parameters: m=4676418, k=4
# fill=25%: P(fp)=0.000482
# fill=50%: P(fp)=0.005670
# fill=75%: P(fp)=0.021276
# fill=95%: P(fp)=0.043368
