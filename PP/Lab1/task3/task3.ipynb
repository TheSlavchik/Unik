# %%
import unittest
from analysis import analyze

# %% [markdown]
# **Юнит тесты**

# %%
unittest.main(module='test_cms', argv=[''], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 7.439s
#
# OK
# Norm Error: 0.7400, Big Error: 3.5620
# Merged Error: 0.0000

# %% [markdown]
# **Оценка зависимости погрешности от параметров алгоритма**

# %%
analyze()
# Out:
#         eps    abs_err   rel_err
# 0  0.001000  26.128817  9.774435
# 1  0.000100   0.776813  0.290571
# 2  0.000010   0.001918  0.000644
# 3  0.000001   0.000000  0.000000
