# %%
import unittest
from analysis import analyze

# %% [markdown]
# **Юнит тесты**

# %%
unittest.main(module='test_cms', argv=[''], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 7.412s
#
# OK
# Norm Error: 0.7429, Big Error: 3.5886
# Merged Error: 0.0000

# %% [markdown]
# **Оценка зависимости погрешности от параметров алгоритма**

# %%
analyze()
# Out:
#         eps    abs_err   rel_err
# 0  0.001000  26.130989  9.768919
# 1  0.000100   0.785828  0.294122
# 2  0.000010   0.001993  0.000679
# 3  0.000001   0.000000  0.000000
