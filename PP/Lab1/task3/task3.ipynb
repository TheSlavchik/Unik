# %%
import unittest
from analysis import analyze

# %% [markdown]
# **Юнит тесты**

# %%
unittest.main(module='test_cms', argv=[''], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 12.102s
#
# OK
# Norm Error: 0.7328, Big Error: 3.5877
# Merged Error: 0.0000

# %% [markdown]
# **Оценка зависимости погрешности от параметров алгоритма**

# %%
analyze()
# Out:
#         eps    abs_err   rel_err
# 0  0.001000  26.112099  9.789781
# 1  0.000100   0.770743  0.289428
# 2  0.000010   0.001843  0.000806
# 3  0.000001   0.000000  0.000000
