# %%
import unittest
from analysis import analyze

# %% [markdown]
# **Юнит тесты**

# %%
unittest.main(module='test_cms', argv=[''], exit=False)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 6.734s
#
# OK
# Norm Error: 0.7359, Big Error: 3.5728
# Merged Error: 0.0000

# %% [markdown]
# **Оценка зависимости погрешности от параметров алгоритма**

# %%
analyze()
# Out:
#         eps    abs_err   rel_err
# 0  0.001000  26.148338  9.832408
# 1  0.000100   0.784538  0.293467
# 2  0.000010   0.002240  0.000745
# 3  0.000001   0.000000  0.000000
